# %%
import matplotlib.pyplot as plt
import numpy as np



round1 = [
    {"c1":64,"c2":64,"fc1":256,"fc2":256,"pct":100.0,"wt_iter":1700,"rr_iter":2000,"wt_test_acc":68.2,"rr_test_acc":69.1,"wt_train_acc":77.5,"rr_train_acc":83.0,"params":4301642,"wt_latency":4.52,"rr_latency":4.52},
    {"c1":61,"c2":61,"fc1":231,"fc2":231,"pct": 86.0,"wt_iter":2400,"rr_iter":2000,"wt_test_acc":69.6,"rr_test_acc":68.8,"wt_train_acc":83.2,"rr_train_acc":81.0,"params":3698697,"wt_latency":4.54,"rr_latency":4.44},
    {"c1":58,"c2":58,"fc1":208,"fc2":208,"pct": 73.6,"wt_iter":2400,"rr_iter":2100,"wt_test_acc":69.5,"rr_test_acc":67.2,"wt_train_acc":82.1,"rr_train_acc":79.1,"params":3166112,"wt_latency":4.29,"rr_latency":4.30},
    {"c1":56,"c2":56,"fc1":188,"fc2":188,"pct": 64.2,"wt_iter":2500,"rr_iter":2500,"wt_test_acc":68.8,"rr_test_acc":69.1,"wt_train_acc":81.7,"rr_train_acc":81.5,"params":2762626,"wt_latency":4.16,"rr_latency":4.07},
    {"c1":54,"c2":54,"fc1":170,"fc2":170,"pct": 56.0,"wt_iter":3100,"rr_iter":2500,"wt_test_acc":69.4,"rr_test_acc":68.6,"wt_train_acc":83.6,"rr_train_acc":80.3,"params":2408840,"wt_latency":4.01,"rr_latency":4.02},
    {"c1":52,"c2":52,"fc1":153,"fc2":153,"pct": 48.5,"wt_iter":2900,"rr_iter":2400,"wt_test_acc":69.3,"rr_test_acc":68.2,"wt_train_acc":81.6,"rr_train_acc":78.8,"params":2087835,"wt_latency":3.93,"rr_latency":3.94},
    {"c1":50,"c2":50,"fc1":138,"fc2":138,"pct": 42.1,"wt_iter":3500,"rr_iter":2600,"wt_test_acc":68.8,"rr_test_acc":68.2,"wt_train_acc":82.5,"rr_train_acc":78.1,"params":1811060,"wt_latency":3.79,"rr_latency":3.80},
    {"c1":48,"c2":48,"fc1":125,"fc2":125,"pct": 36.6,"wt_iter":3500,"rr_iter":3500,"wt_test_acc":67.8,"rr_test_acc":68.4,"wt_train_acc":79.5,"rr_train_acc":81.4,"params":1575263,"wt_latency":3.49,"rr_latency":3.49},
    {"c1":46,"c2":46,"fc1":113,"fc2":113,"pct": 31.7,"wt_iter":3500,"rr_iter":3500,"wt_test_acc":68.3,"rr_test_acc":68.6,"wt_train_acc":78.7,"rr_train_acc":81.7,"params":1365201,"wt_latency":3.43,"rr_latency":3.49},
    {"c1":44,"c2":44,"fc1":102,"fc2":102,"pct": 27.4,"wt_iter":3600,"rr_iter":3500,"wt_test_acc":67.8,"rr_test_acc":68.2,"wt_train_acc":79.0,"rr_train_acc":80.4,"params":1179266,"wt_latency":3.95,"rr_latency":3.95},
    {"c1":42,"c2":42,"fc1": 92,"fc2": 92,"pct": 23.6,"wt_iter":4500,"rr_iter":3500,"wt_test_acc":67.9,"rr_test_acc":67.5,"wt_train_acc":78.9,"rr_train_acc":77.6,"params":1015856,"wt_latency":3.83,"rr_latency":3.84},
    {"c1":40,"c2":40,"fc1": 83,"fc2": 83,"pct": 20.3,"wt_iter":4000,"rr_iter":4400,"wt_test_acc":67.9,"rr_test_acc":67.8,"wt_train_acc":77.4,"rr_train_acc":79.7,"params": 873375,"wt_latency":3.54,"rr_latency":3.50},
    {"c1":38,"c2":38,"fc1": 75,"fc2": 75,"pct": 17.4,"wt_iter":4800,"rr_iter":4600,"wt_test_acc":67.9,"rr_test_acc":68.1,"wt_train_acc":79.3,"rr_train_acc":80.6,"params": 750233,"wt_latency":3.47,"rr_latency":3.49},
    {"c1":37,"c2":37,"fc1": 68,"fc2": 68,"pct": 15.4,"wt_iter":5800,"rr_iter":4200,"wt_test_acc":68.1,"rr_test_acc":67.7,"wt_train_acc":79.4,"rr_train_acc":79.3,"params": 662940,"wt_latency":3.60,"rr_latency":3.59},
    {"c1":36,"c2":36,"fc1": 62,"fc2": 62,"pct": 13.7,"wt_iter":5400,"rr_iter":4800,"wt_test_acc":67.3,"rr_test_acc":66.6,"wt_train_acc":78.1,"rr_train_acc":76.8,"params": 588698,"wt_latency":3.36,"rr_latency":3.33},
    {"c1":35,"c2":35,"fc1": 56,"fc2": 56,"pct": 12.0,"wt_iter":5200,"rr_iter":4600,"wt_test_acc":66.8,"rr_test_acc":66.8,"wt_train_acc":75.4,"rr_train_acc":76.7,"params": 517618,"wt_latency":3.31,"rr_latency":3.31},
    {"c1":34,"c2":34,"fc1": 51,"fc2": 51,"pct": 10.7,"wt_iter":6000,"rr_iter":4200,"wt_test_acc":66.6,"rr_test_acc":66.1,"wt_train_acc":75.7,"rr_train_acc":75.0,"params": 458517,"wt_latency":3.27,"rr_latency":3.28},
    {"c1":33,"c2":33,"fc1": 46,"fc2": 46,"pct":  9.3,"wt_iter":7800,"rr_iter":6000,"wt_test_acc":67.6,"rr_test_acc":66.4,"wt_train_acc":78.6,"rr_train_acc":78.1,"params": 402044,"wt_latency":3.24,"rr_latency":3.23},
    {"c1":32,"c2":32,"fc1": 42,"fc2": 42,"pct":  8.3,"wt_iter":5600,"rr_iter":6800,"wt_test_acc":65.9,"rr_test_acc":66.1,"wt_train_acc":73.7,"rr_train_acc":78.0,"params": 356486,"wt_latency":2.04,"rr_latency":2.04},
    {"c1":31,"c2":31,"fc1": 38,"fc2": 38,"pct":  7.3,"wt_iter":7200,"rr_iter":5800,"wt_test_acc":66.6,"rr_test_acc":67.0,"wt_train_acc":75.4,"rr_train_acc":76.6,"params": 313026,"wt_latency":2.07,"rr_latency":2.01},
    {"c1":30,"c2":30,"fc1": 35,"fc2": 35,"pct":  6.5,"wt_iter":8200,"rr_iter":6400,"wt_test_acc":66.5,"rr_test_acc":66.0,"wt_train_acc":74.8,"rr_train_acc":75.9,"params": 279425,"wt_latency":2.02,"rr_latency":1.97},
]



KEYS_TO_AVG = ["wt_iter", "rr_iter", "wt_test_acc", "rr_test_acc",
               "wt_train_acc", "rr_train_acc", "wt_latency", "rr_latency"]

def avg_rounds(r1, r2, r3):
    assert len(r1) == len(r2) == len(r3)
    averaged, stdevs = [], []
    for i in range(len(r1)):
        row = dict(r1[i])
        std_row = {}
        for k in KEYS_TO_AVG:
            vals = [r1[i][k], r2[i][k], r3[i][k]]
            row[k] = np.mean(vals)
            std_row[k] = np.std(vals, ddof=1)
        averaged.append(row)
        stdevs.append(std_row)
    return averaged, stdevs

results, stdevs = avg_rounds(round1, round2, round3)


c1_vals  = [r["c1"]           for r in results]
fc1_vals = [r["fc1"]          for r in results]
pct      = [r["pct"]          for r in results]

wt_iters = np.array([r["wt_iter"]      for r in results])
rr_iters = np.array([r["rr_iter"]      for r in results])
wt_test  = np.array([r["wt_test_acc"]  for r in results])
rr_test  = np.array([r["rr_test_acc"]  for r in results])
wt_train = np.array([r["wt_train_acc"] for r in results])
rr_train = np.array([r["rr_train_acc"] for r in results])
params_k = np.array([r["params"] / 1e3 for r in results])

# stds
wt_iters_std = np.array([s["wt_iter"]      for s in stdevs])
rr_iters_std = np.array([s["rr_iter"]      for s in stdevs])
wt_test_std  = np.array([s["wt_test_acc"]  for s in stdevs])
rr_test_std  = np.array([s["rr_test_acc"]  for s in stdevs])
wt_train_std = np.array([s["wt_train_acc"] for s in stdevs])
rr_train_std = np.array([s["rr_train_acc"] for s in stdevs])

# Generalization gap = train_acc - test_acc
wt_gap = wt_train - wt_test
rr_gap = rr_train - rr_test
wt_gap_std = np.sqrt(wt_train_std**2 + wt_test_std**2)
rr_gap_std = np.sqrt(rr_train_std**2 + rr_test_std**2)

# WT - RR test accuracy delta
delta_test = wt_test - rr_test
delta_test_std = np.sqrt(wt_test_std**2 + rr_test_std**2)

x = np.array(c1_vals)

WT_COLOR = "mediumpurple"
RR_COLOR = "mediumseagreen"


c1_to_fc1 = {r["c1"]: r["fc1"] for r in results}

def _add_dual_xaxis(ax):
    ax2 = ax.twiny()
    ax2.set_xlim(ax.get_xlim())
    tick_positions = x
    tick_labels = [str(c1_to_fc1[v]) for v in x]
    ax2.set_xticks(tick_positions)
    ax2.set_xticklabels(tick_labels, fontsize=6.5, rotation=45, ha="left")
    ax2.set_xlabel("FC Neurons Remaining", fontsize=8.5, labelpad=6)
    return ax2

def _setup_ax(ax, title, ylabel, show_legend=True):
    ax.invert_xaxis()
    ax.set_xlabel("Conv Filters Remaining", fontsize=9)
    ax.set_ylabel(ylabel, fontsize=9)
    ax.set_title(title, fontsize=10)
    if show_legend:
        ax.legend(fontsize=8.5)
    ax.grid(True, alpha=0.3)
    _add_dual_xaxis(ax)


fig, axes = plt.subplots(2, 2, figsize=(13, 10))
plt.subplots_adjust(hspace=0.55, wspace=0.35)

# Early-stop iteration
ax = axes[0, 0]
ax.plot(x, wt_iters, color=WT_COLOR, marker="o", ms=4, label="Winning Ticket")
ax.plot(x, rr_iters, color=RR_COLOR, marker="s", ms=4, label="Random Reinit")
_setup_ax(ax, "(a)  Early-Stop Iteration", "Early-Stop Iteration (Val.)")

# Test accuracy
ax = axes[0, 1]
ax.plot(x, wt_test, color=WT_COLOR, marker="o", ms=4, label="Winning Ticket")
ax.plot(x, rr_test, color=RR_COLOR, marker="s", ms=4, label="Random Reinit")
_setup_ax(ax, "(b)  Test Accuracy at Early-Stop", "Accuracy at early stop - Test Accuracy (%)")

#Train accuracy
ax = axes[1, 0]
ax.plot(x, wt_train, color=WT_COLOR, marker="o", ms=4, label="Winning Ticket")
ax.plot(x, rr_train, color=RR_COLOR, marker="s", ms=4, label="Random Reinit")
_setup_ax(ax, "(c)  Train Accuracy at Early-Stop", "Accuracy at early stop - Train Accuracy (%)")

# WT − RR test accuracy delta
ax = axes[1, 1]
ax.axhline(0, color="gray", lw=1.0, ls="--")
ax.fill_between(x, delta_test, 0,
                where=(delta_test >= 0), alpha=0.15, color=WT_COLOR,
                label="WT leads")
ax.fill_between(x, delta_test, 0,
                where=(delta_test < 0),  alpha=0.15, color=RR_COLOR,
                label="RR leads")
ax.plot(x, delta_test, color="steelblue", marker="D", ms=4, label="WT − RR")
ax.set_ylabel("WT − RR Test Acc (%)", fontsize=9)
ax.set_title("(d)  WT vs RR Test Accuracy Difference\n"
             "Above zero = WT better; below zero = RR better", fontsize=10)
ax.invert_xaxis()
ax.set_xlabel("Conv Filters Remaining", fontsize=9)
ax.legend(fontsize=8.5)
ax.grid(True, alpha=0.3)
_add_dual_xaxis(ax)

plt.suptitle(
    "Conv2 on CIFAR-10 – Structured LTH Evaluation (Mean over 3 Runs)\n"
    "Bottom x-axis: Conv filters remaining  |  Top x-axis: FC neurons remaining",
    fontsize=13, y=1.02)

plt.savefig("conv2_lth_averaged.pdf", bbox_inches="tight")
plt.savefig("conv2_lth_averaged.png", bbox_inches="tight", dpi=150)
plt.show()
print("Saved conv2_lth_averaged.pdf and .png")
# Out:
# Saved conv2_lth_averaged.pdf and .png

# %%
import matplotlib.pyplot as plt
import numpy as np



round1 = [
    {"c1":64,"c2":64,"fc1":256,"fc2":256,"pct":100.0,"wt_iter":1700,"rr_iter":2000,"wt_test_acc":68.2,"rr_test_acc":69.1,"wt_train_acc":77.5,"rr_train_acc":83.0,"params":4301642,"wt_latency":4.52,"rr_latency":4.52},
    {"c1":61,"c2":61,"fc1":231,"fc2":231,"pct": 86.0,"wt_iter":2400,"rr_iter":2000,"wt_test_acc":69.6,"rr_test_acc":68.8,"wt_train_acc":83.2,"rr_train_acc":81.0,"params":3698697,"wt_latency":4.54,"rr_latency":4.44},
    {"c1":58,"c2":58,"fc1":208,"fc2":208,"pct": 73.6,"wt_iter":2400,"rr_iter":2100,"wt_test_acc":69.5,"rr_test_acc":67.2,"wt_train_acc":82.1,"rr_train_acc":79.1,"params":3166112,"wt_latency":4.29,"rr_latency":4.30},
    {"c1":56,"c2":56,"fc1":188,"fc2":188,"pct": 64.2,"wt_iter":2500,"rr_iter":2500,"wt_test_acc":68.8,"rr_test_acc":69.1,"wt_train_acc":81.7,"rr_train_acc":81.5,"params":2762626,"wt_latency":4.16,"rr_latency":4.07},
    {"c1":52,"c2":52,"fc1":153,"fc2":153,"pct": 48.5,"wt_iter":3000,"rr_iter":2200,"wt_test_acc":68.3,"rr_test_acc":68.6,"wt_train_acc":80.9,"rr_train_acc":78.0,"params":2087835,"wt_latency":3.93,"rr_latency":3.90},
    {"c1":50,"c2":50,"fc1":138,"fc2":138,"pct": 42.1,"wt_iter":3800,"rr_iter":2800,"wt_test_acc":68.9,"rr_test_acc":68.1,"wt_train_acc":84.2,"rr_train_acc":79.1,"params":1811060,"wt_latency":3.80,"rr_latency":3.79},
    {"c1":48,"c2":48,"fc1":125,"fc2":125,"pct": 36.6,"wt_iter":3600,"rr_iter":3400,"wt_test_acc":68.3,"rr_test_acc":67.5,"wt_train_acc":80.3,"rr_train_acc":80.1,"params":1575263,"wt_latency":3.51,"rr_latency":3.48},
    {"c1":46,"c2":46,"fc1":113,"fc2":113,"pct": 31.7,"wt_iter":3800,"rr_iter":3200,"wt_test_acc":67.6,"rr_test_acc":68.5,"wt_train_acc":80.1,"rr_train_acc":80.3,"params":1365201,"wt_latency":3.43,"rr_latency":3.47},
    {"c1":44,"c2":44,"fc1":102,"fc2":102,"pct": 27.4,"wt_iter":3600,"rr_iter":3600,"wt_test_acc":67.0,"rr_test_acc":68.0,"wt_train_acc":78.2,"rr_train_acc":79.2,"params":1179266,"wt_latency":3.98,"rr_latency":3.95},
    {"c1":42,"c2":42,"fc1": 92,"fc2": 92,"pct": 23.6,"wt_iter":4600,"rr_iter":4200,"wt_test_acc":67.9,"rr_test_acc":68.5,"wt_train_acc":80.3,"rr_train_acc":80.3,"params":1015856,"wt_latency":3.87,"rr_latency":3.85},
    {"c1":40,"c2":40,"fc1": 83,"fc2": 83,"pct": 20.3,"wt_iter":4600,"rr_iter":4200,"wt_test_acc":67.0,"rr_test_acc":66.8,"wt_train_acc":77.8,"rr_train_acc":78.6,"params": 873375,"wt_latency":3.53,"rr_latency":3.51},
    {"c1":38,"c2":38,"fc1": 75,"fc2": 75,"pct": 17.4,"wt_iter":5200,"rr_iter":3400,"wt_test_acc":67.9,"rr_test_acc":65.8,"wt_train_acc":79.0,"rr_train_acc":74.3,"params": 750233,"wt_latency":3.52,"rr_latency":3.49},
    {"c1":37,"c2":37,"fc1": 68,"fc2": 68,"pct": 15.4,"wt_iter":5600,"rr_iter":5600,"wt_test_acc":67.3,"rr_test_acc":67.2,"wt_train_acc":77.7,"rr_train_acc":81.2,"params": 662940,"wt_latency":3.59,"rr_latency":3.59},
    {"c1":36,"c2":36,"fc1": 62,"fc2": 62,"pct": 13.7,"wt_iter":5000,"rr_iter":5200,"wt_test_acc":66.2,"rr_test_acc":67.7,"wt_train_acc":76.0,"rr_train_acc":78.7,"params": 588698,"wt_latency":3.34,"rr_latency":3.34},
    {"c1":35,"c2":35,"fc1": 56,"fc2": 56,"pct": 12.0,"wt_iter":5000,"rr_iter":5000,"wt_test_acc":66.0,"rr_test_acc":67.8,"wt_train_acc":74.6,"rr_train_acc":78.8,"params": 517618,"wt_latency":3.36,"rr_latency":3.29},
    {"c1":34,"c2":34,"fc1": 51,"fc2": 51,"pct": 10.7,"wt_iter":6000,"rr_iter":4400,"wt_test_acc":66.1,"rr_test_acc":66.0,"wt_train_acc":76.9,"rr_train_acc":74.1,"params": 458517,"wt_latency":3.28,"rr_latency":3.32},
    {"c1":33,"c2":33,"fc1": 46,"fc2": 46,"pct":  9.3,"wt_iter":6600,"rr_iter":6000,"wt_test_acc":66.9,"rr_test_acc":66.7,"wt_train_acc":77.5,"rr_train_acc":77.1,"params": 402044,"wt_latency":3.25,"rr_latency":3.26},
    {"c1":32,"c2":32,"fc1": 42,"fc2": 42,"pct":  8.3,"wt_iter":6200,"rr_iter":6600,"wt_test_acc":66.0,"rr_test_acc":66.5,"wt_train_acc":74.2,"rr_train_acc":76.5,"params": 356486,"wt_latency":2.00,"rr_latency":2.02},
    {"c1":31,"c2":31,"fc1": 38,"fc2": 38,"pct":  7.3,"wt_iter":6400,"rr_iter":6600,"wt_test_acc":66.0,"rr_test_acc":66.5,"wt_train_acc":74.0,"rr_train_acc":75.7,"params": 313026,"wt_latency":2.01,"rr_latency":1.97},
    {"c1":30,"c2":30,"fc1": 35,"fc2": 35,"pct":  6.5,"wt_iter":8400,"rr_iter":6400,"wt_test_acc":66.5,"rr_test_acc":65.3,"wt_train_acc":76.5,"rr_train_acc":73.3,"params": 279425,"wt_latency":2.00,"rr_latency":2.00},
]

round3 = [
    {"c1":64,"c2":64,"fc1":256,"fc2":256,"pct":100.0,"wt_iter":2800,"rr_iter":2000,"wt_test_acc":70.1,"rr_test_acc":69.4,"wt_train_acc":90.0,"rr_train_acc":82.1,"params":4301642,"wt_latency":4.58,"rr_latency":4.69},
    {"c1":61,"c2":61,"fc1":231,"fc2":231,"pct": 86.0,"wt_iter":2200,"rr_iter":2800,"wt_test_acc":69.5,"rr_test_acc":69.6,"wt_train_acc":82.9,"rr_train_acc":87.7,"params":3698697,"wt_latency":4.50,"rr_latency":4.48},
    {"c1":58,"c2":58,"fc1":208,"fc2":208,"pct": 73.6,"wt_iter":2800,"rr_iter":2400,"wt_test_acc":68.9,"rr_test_acc":68.3,"wt_train_acc":85.3,"rr_train_acc":80.9,"params":3166112,"wt_latency":4.36,"rr_latency":4.33},
    {"c1":56,"c2":56,"fc1":188,"fc2":188,"pct": 64.2,"wt_iter":2800,"rr_iter":2400,"wt_test_acc":68.7,"rr_test_acc":68.8,"wt_train_acc":82.7,"rr_train_acc":80.8,"params":2762626,"wt_latency":4.09,"rr_latency":4.10},
    {"c1":54,"c2":54,"fc1":170,"fc2":170,"pct": 56.0,"wt_iter":2800,"rr_iter":2200,"wt_test_acc":68.3,"rr_test_acc":67.9,"wt_train_acc":82.9,"rr_train_acc":79.0,"params":2408840,"wt_latency":4.08,"rr_latency":4.05},
    {"c1":52,"c2":52,"fc1":153,"fc2":153,"pct": 48.5,"wt_iter":2800,"rr_iter":3200,"wt_test_acc":68.1,"rr_test_acc":69.0,"wt_train_acc":80.2,"rr_train_acc":82.9,"params":2087835,"wt_latency":3.93,"rr_latency":3.94},
    {"c1":50,"c2":50,"fc1":138,"fc2":138,"pct": 42.1,"wt_iter":2800,"rr_iter":3200,"wt_test_acc":67.9,"rr_test_acc":69.1,"wt_train_acc":78.5,"rr_train_acc":81.8,"params":1811060,"wt_latency":3.83,"rr_latency":3.81},
    {"c1":48,"c2":48,"fc1":125,"fc2":125,"pct": 36.6,"wt_iter":3400,"rr_iter":3000,"wt_test_acc":68.4,"rr_test_acc":68.4,"wt_train_acc":81.5,"rr_train_acc":80.6,"params":1575263,"wt_latency":3.51,"rr_latency":3.52},
    {"c1":46,"c2":46,"fc1":113,"fc2":113,"pct": 31.7,"wt_iter":3600,"rr_iter":2800,"wt_test_acc":68.6,"rr_test_acc":67.8,"wt_train_acc":80.8,"rr_train_acc":76.4,"params":1365201,"wt_latency":3.45,"rr_latency":3.48},
    {"c1":44,"c2":44,"fc1":102,"fc2":102,"pct": 27.4,"wt_iter":3800,"rr_iter":3400,"wt_test_acc":68.7,"rr_test_acc":68.4,"wt_train_acc":80.0,"rr_train_acc":80.4,"params":1179266,"wt_latency":4.03,"rr_latency":4.02},
    {"c1":42,"c2":42,"fc1": 92,"fc2": 92,"pct": 23.6,"wt_iter":4400,"rr_iter":4000,"wt_test_acc":68.1,"rr_test_acc":67.0,"wt_train_acc":80.4,"rr_train_acc":77.7,"params":1015856,"wt_latency":3.88,"rr_latency":3.87},
    {"c1":40,"c2":40,"fc1": 83,"fc2": 83,"pct": 20.3,"wt_iter":4000,"rr_iter":4400,"wt_test_acc":67.9,"rr_test_acc":67.8,"wt_train_acc":77.4,"rr_train_acc":79.7,"params": 873375,"wt_latency":3.54,"rr_latency":3.50},
    {"c1":38,"c2":38,"fc1": 75,"fc2": 75,"pct": 17.4,"wt_iter":4800,"rr_iter":4600,"wt_test_acc":67.9,"rr_test_acc":68.1,"wt_train_acc":79.3,"rr_train_acc":80.6,"params": 750233,"wt_latency":3.47,"rr_latency":3.49},
    {"c1":37,"c2":37,"fc1": 68,"fc2": 68,"pct": 15.4,"wt_iter":5800,"rr_iter":4200,"wt_test_acc":68.1,"rr_test_acc":67.7,"wt_train_acc":79.4,"rr_train_acc":79.3,"params": 662940,"wt_latency":3.60,"rr_latency":3.59},
    {"c1":36,"c2":36,"fc1": 62,"fc2": 62,"pct": 13.7,"wt_iter":5400,"rr_iter":4800,"wt_test_acc":67.3,"rr_test_acc":66.6,"wt_train_acc":78.1,"rr_train_acc":76.8,"params": 588698,"wt_latency":3.36,"rr_latency":3.33},
    {"c1":35,"c2":35,"fc1": 56,"fc2": 56,"pct": 12.0,"wt_iter":5200,"rr_iter":4600,"wt_test_acc":66.8,"rr_test_acc":66.8,"wt_train_acc":75.4,"rr_train_acc":76.7,"params": 517618,"wt_latency":3.31,"rr_latency":3.31},
    {"c1":34,"c2":34,"fc1": 51,"fc2": 51,"pct": 10.7,"wt_iter":6000,"rr_iter":4200,"wt_test_acc":66.6,"rr_test_acc":66.1,"wt_train_acc":75.7,"rr_train_acc":75.0,"params": 458517,"wt_latency":3.27,"rr_latency":3.28},
    {"c1":33,"c2":33,"fc1": 46,"fc2": 46,"pct":  9.3,"wt_iter":7800,"rr_iter":6000,"wt_test_acc":67.6,"rr_test_acc":66.4,"wt_train_acc":78.6,"rr_train_acc":78.1,"params": 402044,"wt_latency":3.24,"rr_latency":3.23},
    {"c1":32,"c2":32,"fc1": 42,"fc2": 42,"pct":  8.3,"wt_iter":5600,"rr_iter":6800,"wt_test_acc":65.9,"rr_test_acc":66.1,"wt_train_acc":73.7,"rr_train_acc":78.0,"params": 356486,"wt_latency":2.04,"rr_latency":2.04},
    {"c1":31,"c2":31,"fc1": 38,"fc2": 38,"pct":  7.3,"wt_iter":7200,"rr_iter":5800,"wt_test_acc":66.6,"rr_test_acc":67.0,"wt_train_acc":75.4,"rr_train_acc":76.6,"params": 313026,"wt_latency":2.07,"rr_latency":2.01},
    {"c1":30,"c2":30,"fc1": 35,"fc2": 35,"pct":  6.5,"wt_iter":8200,"rr_iter":6400,"wt_test_acc":66.5,"rr_test_acc":66.0,"wt_train_acc":74.8,"rr_train_acc":75.9,"params": 279425,"wt_latency":2.02,"rr_latency":1.97},
]



KEYS_TO_AVG = ["wt_iter", "rr_iter", "wt_test_acc", "rr_test_acc",
               "wt_train_acc", "rr_train_acc", "wt_latency", "rr_latency"]

def avg_rounds(r1, r2, r3):
    assert len(r1) == len(r2) == len(r3)
    averaged, stdevs = [], []
    for i in range(len(r1)):
        row = dict(r1[i])
        std_row = {}
        for k in KEYS_TO_AVG:
            vals = [r1[i][k], r2[i][k], r3[i][k]]
            row[k] = np.mean(vals)
            std_row[k] = np.std(vals, ddof=1)
        averaged.append(row)
        stdevs.append(std_row)
    return averaged, stdevs

results, stdevs = avg_rounds(round1, round2, round3)

c1_vals  = [r["c1"]           for r in results]
fc1_vals = [r["fc1"]          for r in results]
pct      = [r["pct"]          for r in results]

wt_iters = np.array([r["wt_iter"]      for r in results])
rr_iters = np.array([r["rr_iter"]      for r in results])
wt_test  = np.array([r["wt_test_acc"]  for r in results])
rr_test  = np.array([r["rr_test_acc"]  for r in results])
wt_train = np.array([r["wt_train_acc"] for r in results])
rr_train = np.array([r["rr_train_acc"] for r in results])
params_k = np.array([r["params"] / 1e3 for r in results])

# stds
wt_iters_std = np.array([s["wt_iter"]      for s in stdevs])
rr_iters_std = np.array([s["rr_iter"]      for s in stdevs])
wt_test_std  = np.array([s["wt_test_acc"]  for s in stdevs])
rr_test_std  = np.array([s["rr_test_acc"]  for s in stdevs])
wt_train_std = np.array([s["wt_train_acc"] for s in stdevs])
rr_train_std = np.array([s["rr_train_acc"] for s in stdevs])

# Generalization gap = train_acc - test_acc
wt_gap = wt_train - wt_test
rr_gap = rr_train - rr_test
wt_gap_std = np.sqrt(wt_train_std**2 + wt_test_std**2)
rr_gap_std = np.sqrt(rr_train_std**2 + rr_test_std**2)

# WT - RR test accuracy delta
delta_test = wt_test - rr_test
delta_test_std = np.sqrt(wt_test_std**2 + rr_test_std**2)

x = np.array(pct)

WT_COLOR = "mediumpurple"
RR_COLOR = "mediumseagreen"

def _setup_ax(ax, title, ylabel, show_legend=True):
    ax.invert_xaxis()
    ax.set_xlabel("Weights Remaining (%)", fontsize=9)
    ax.set_ylabel(ylabel, fontsize=9)
    ax.set_title(title, fontsize=10)
    if show_legend:
        ax.legend(fontsize=8.5)
    ax.grid(True, alpha=0.3)


fig, axes = plt.subplots(2, 2, figsize=(13, 10))
plt.subplots_adjust(hspace=0.45, wspace=0.35)

# Early-stop iteration
ax = axes[0, 0]
ax.plot(x, wt_iters, color=WT_COLOR, marker="o", ms=4, label="Winning Ticket")
ax.plot(x, rr_iters, color=RR_COLOR, marker="s", ms=4, label="Random Reinit")
_setup_ax(ax, "(a)  Early-Stop Iteration", "Early-Stop Iteration (Val.)")

# Test accuracy
ax = axes[0, 1]
ax.plot(x, wt_test, color=WT_COLOR, marker="o", ms=4, label="Winning Ticket")
ax.plot(x, rr_test, color=RR_COLOR, marker="s", ms=4, label="Random Reinit")
_setup_ax(ax, "(b)  Test Accuracy at Early-Stop", " Accuracy at early stop - Test Accuracy (%)")

# Train accuracy
ax = axes[1, 0]
ax.plot(x, wt_train, color=WT_COLOR, marker="o", ms=4, label="Winning Ticket")
ax.plot(x, rr_train, color=RR_COLOR, marker="s", ms=4, label="Random Reinit")
_setup_ax(ax, "(c)  Train Accuracy at Early-Stop", "Accuracy at early stop - Train Accuracy (%)")

# WT − RR test accuracy delta
ax = axes[1, 1]
ax.axhline(0, color="gray", lw=1.0, ls="--")
ax.fill_between(x, delta_test, 0,
                where=(delta_test >= 0), alpha=0.15, color=WT_COLOR,
                label="WT leads")
ax.fill_between(x, delta_test, 0,
                where=(delta_test < 0),  alpha=0.15, color=RR_COLOR,
                label="RR leads")
ax.plot(x, delta_test, color="steelblue", marker="D", ms=4, label="WT − RR")
ax.set_ylabel("WT − RR Test Acc (%)", fontsize=9)
ax.set_title("(d)  WT vs RR Test Accuracy Difference\n"
             "Above zero = WT better; below zero = RR better", fontsize=10)
ax.invert_xaxis()
ax.set_xlabel("Weights Remaining (%)", fontsize=9)
ax.legend(fontsize=8.5)
ax.grid(True, alpha=0.3)

plt.suptitle(
    "Conv2 on CIFAR-10 – Structured LTH Evaluation (Mean over 3 Runs)\n"
    "x-axis: Percentage of weights remaining after structured pruning",
    fontsize=13, y=1.02)

plt.savefig("conv2_lth_averaged.pdf", bbox_inches="tight")
plt.savefig("conv2_lth_averaged.png", bbox_inches="tight", dpi=150)
plt.show()
print("Saved conv2_lth_averaged.pdf and .png")
# Out:
# Saved conv2_lth_averaged.pdf and .png
